# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Request a table 
import requests
from bs4 import BeautifulSoup
from IPython.display import display, HTML

# URL of the page
url = 'https://theghub.org/groups/ismip6/wiki/ISMIP6-Projections-Antarctica'

# Fetch the HTML content
response = requests.get(url)
html_content = response.text

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# display(HTML(str(soup)))
# specific table:
tables = soup.find_all('table')
display(HTML(str(tables[2])))  # Adjust index as necessary
# Out:
# <table>
# <tr>
# <td colspan="7" style="text-align:left;"><i><b>Table A1: Variable request for ISMIP6 projections.</b></i>
# <br/> <b>Bold names</b> or “alias” indicate a change compared to initMIP, to align the request with the CMIP6 official MIPtable “IyrAnt” or names in the CF convention. <br/>If possible please use the new names, and if not, the name change will occur when your files are checked for CMIP compliance. <br/> The first entry should be that from which the simulation starts. Fields such as surface mass balance flux should be what was applied as boundary conditions.<i> <br/> </i></td>
# </tr>
# <tr>
# <td colspan="7"><i><b>2D variables requested yearly as snashots (end of the year) for type ST and as yearly average for type FL.</b></i></td>
# </tr>
# <tr>
# <td style="text-align:left;"><b>Variable</b> </td>
# <td><b>Dim</b></td>
# <td><b>Type</b></td>
# <td><b>Variable Name</b></td>
# <td><b>Standard Name</b></td>
# <td><b>Units</b></td>
# <td><b>Comment</b></td>
# ...

# %%
# url = 'https://theghub.org/groups/ismip6/wiki/ISMIP6-Projections-Antarctica'
# tables = pd.read_html(url)  # This fetches and parses all tables into a list of DataFrames

# %% [markdown]
# <div style="position: relative; width: 100%;">
#     <hr style="position: absolute; left: 0; width: 50%; border: none; height: 2px; background-color: yellow; border-style: dotted;">
# </div>

# %% [markdown]
# <span style="font-size:14pt; font-family:'Courier New', monospace; color:black"> <b>Basic Scraping to DF::</b> Alternate to the above. 20240429; I am very busy at the moment to populate and fair this. But It should bemade available to BASIC community soon. Below is the rough version. This nbk should be made to include the selerium?? (other advanced scraper to handel java)<br>

# %%
# Scrape tables
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page containing the table
url = 'https://theghub.org/groups/ismip6/wiki/ISMIP6-Projections-Antarctica'

# Fetch the HTML content
response = requests.get(url)
html_content = response.text

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Extract all tables from the HTML
tables = soup.find_all('table')
print("Total tables found:", len(tables))

# Check if you are accessing the correct table
if len(tables) > 0:
    # Print the first few rows of the table to check it
    print(tables[0].prettify()[:1000])  # Modify the index as necessary
else:
    print("No tables found")

# %%
df = pd.read_html(str(tables[2]))[0]

# %%
print(df.head())  # Prints the first few rows of the DataFrame
